# %%
# import libraries

import os, sys, email
import numpy as np 
import pandas as pd

# %%
# show 55 columns and rows

pd.set_option('display.max_columns', 55)
pd.set_option('display.max_rows', 55)

# %%
# read the data into a DataFrame

emails_df = pd.read_csv('../data/enron_05_17_2015_with_labels_v2_100K_chunk_1_of_6.csv')
print(emails_df.shape)
# Out:
# (100000, 52)

# %%
emails_df.dtypes
# Out:
# Unnamed: 0          int64
# Message-ID         object
# Date               object
# From               object
# To                 object
# Subject            object
# X-From             object
# X-To               object
# X-cc               object
# X-bcc              object
# X-Folder           object
# X-Origin           object
# X-FileName         object
# content            object
# user               object
# Cat_1_level_1     float64
# Cat_1_level_2     float64
# Cat_1_weight      float64
# Cat_2_level_1     float64
# Cat_2_level_2     float64
# Cat_2_weight      float64
# Cat_3_level_1     float64
# Cat_3_level_2     float64
# Cat_3_weight      float64
# Cat_4_level_1     float64
# Cat_4_level_2     float64
# Cat_4_weight      float64
# Cat_5_level_1     float64
# Cat_5_level_2     float64
# Cat_5_weight      float64
# Cat_6_level_1     float64
# Cat_6_level_2     float64
# Cat_6_weight      float64
# Cat_7_level_1     float64
# Cat_7_level_2     float64
# ...

# %%
type(emails_df)
# Out:
# pandas.core.frame.DataFrame

# %%
emails_df.loc[emails_df['Cat_1_level_1'].notnull(),]
# Out:
#        Unnamed: 0                                     Message-ID  \
# 379           379   <9831685.1075855725804.JavaMail.evans@thyme>
# 381           381  <21041312.1075855725847.JavaMail.evans@thyme>
# 2139         2139   <5907100.1075858639941.JavaMail.evans@thyme>
# 2140         2140  <26625142.1075858639964.JavaMail.evans@thyme>
# 2232         2232  <19730598.1075858642129.JavaMail.evans@thyme>
# ...           ...                                            ...
# 84186       84186  <15018793.1075853923235.JavaMail.evans@thyme>
# 89217       89217    <668222.1075863672930.JavaMail.evans@thyme>
# 89301       89301  <19247154.1075854433719.JavaMail.evans@thyme>
# 89920       89920  <18786165.1075854496769.JavaMail.evans@thyme>
# 92812       92812  <33132006.1075845100060.JavaMail.evans@thyme>
#
#                       Date                                     From  \
# 379    2001-03-15 14:45:00   frozenset({'phillip.allen@enron.com'})
# ...

# %%
emails_df.loc[:,'Cat_1_level_1':].sum()
# Out:
# Cat_1_level_1     210.0
# Cat_1_level_2     417.0
# Cat_1_weight      354.0
# Cat_2_level_1     430.0
# Cat_2_level_2     866.0
# Cat_2_weight      322.0
# Cat_3_level_1     430.0
# Cat_3_level_2     797.0
# Cat_3_weight      267.0
# Cat_4_level_1     305.0
# Cat_4_level_2     714.0
# Cat_4_weight      165.0
# Cat_5_level_1     184.0
# Cat_5_level_2     397.0
# Cat_5_weight       88.0
# Cat_6_level_1      71.0
# Cat_6_level_2     155.0
# Cat_6_weight       32.0
# Cat_7_level_1      37.0
# Cat_7_level_2      79.0
# Cat_7_weight       11.0
# Cat_8_level_1       7.0
# Cat_8_level_2      22.0
# Cat_8_weight        2.0
# Cat_9_level_1       4.0
# Cat_9_level_2      12.0
# Cat_9_weight        1.0
# Cat_10_level_1      4.0
# Cat_10_level_2     13.0
# Cat_10_weight       1.0
# Cat_11_level_1      0.0
# Cat_11_level_2      0.0
# Cat_11_weight       0.0
# Cat_12_level_1      0.0
# Cat_12_level_2      0.0
# Cat_12_weight       0.0
# labeled           210.0
# dtype: float64

# %%
emails_df.head(100)
# Out:
#     Unnamed: 0                                     Message-ID  \
# 0            0  <18782981.1075855378110.JavaMail.evans@thyme>
# 1            1  <15464986.1075855378456.JavaMail.evans@thyme>
# 2            2  <24216240.1075855687451.JavaMail.evans@thyme>
# 3            3  <13505866.1075863688222.JavaMail.evans@thyme>
# 4            4  <30922949.1075863688243.JavaMail.evans@thyme>
# ..         ...                                            ...
# 95          95  <29919154.1075855689201.JavaMail.evans@thyme>
# 96          96   <4511963.1075855689223.JavaMail.evans@thyme>
# 97          97  <33111317.1075855689245.JavaMail.evans@thyme>
# 98          98   <1665326.1075855689266.JavaMail.evans@thyme>
# 99          99   <4752513.1075855689288.JavaMail.evans@thyme>
#
#                    Date                                    From  \
# 0   2001-05-14 23:39:00  frozenset({'phillip.allen@enron.com'})
# 1   2001-05-04 20:51:00  frozenset({'phillip.allen@enron.com'})
# ...

# %%
emails_df.iloc[1,13]
# Out:
# "Traveling to have a business meeting takes the fun out of the trip. Especially if you have to prepare a presentation. I would suggest holding the business plan meetings here then take a trip without any formal business meetings. I would even try and get some honest opinions on whether a trip is even desired or necessary. As far as the business meetings, I think it would be more productive to try and stimulate discussions across the different groups about what is working and what is not. Too often the presenter speaks and the others are quiet just waiting for their turn. The meetings might be better if held in a round table discussion format. My suggestion for where to go is Austin. Play golf and rent a ski boat and jet ski's. Flying somewhere takes too much time."
